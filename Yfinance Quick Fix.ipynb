# %%
import yfinance as yf
import datetime
from pandas_datareader import data as pdr

# %%
#Load the database and read it 

ticker = "ETH-USD"
start = "2018-01-01"
end = datetime.datetime.now()

df = pdr.get_data_yahoo(ticker, start, end)

df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 7
#       4 start = "2017-01-01"
#       5 end = datetime.datetime.now()
# ----> 7 df = pdr.get_data_yahoo(ticker, start, end)
#       9 df
#
# File ~/.local/lib/python3.8/site-packages/pandas_datareader/data.py:80, in get_data_yahoo(*args, **kwargs)
#      79 def get_data_yahoo(*args, **kwargs):
# ---> 80     return YahooDailyReader(*args, **kwargs).read()
#
# File ~/.local/lib/python3.8/site-packages/pandas_datareader/base.py:253, in _DailyBaseReader.read(self)
#     251 # If a single symbol, (e.g., 'GOOG')
#     252 if isinstance(self.symbols, (string_types, int)):
# --> 253     df = self._read_one_data(self.url, params=self._get_params(self.symbols))
#     254 # Or multiple symbols, (e.g., ['GOOG', 'AAPL', 'MSFT'])
#     255 elif isinstance(self.symbols, DataFrame):
#
# File ~/.local/lib/python3.8/site-packages/pandas_datareader/yahoo/daily.py:153, in YahooDailyReader._read_one_data(self, url, params)
#     151 try:
#     152     j = json.loads(re.search(ptrn, resp.text, re.DOTALL).group(1))
# --> 153     data = j["context"]["dispatcher"]["stores"]["HistoricalPriceStore"]
#     154 except KeyError:
#     155     msg = "No data fetched for symbol {} using {}"
#
# TypeError: string indices must be integers

# %%
import datetime
import yfinance as yf
yf.pdr_override() # <== that's all it takes :-)

ticker = "ETH-USD"
start = "2018-01-01"
end = datetime.datetime.now()

df = pdr.get_data_yahoo(ticker, start, end)

df
# Out:
# [*********************100%***********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2018-01-01   755.757019   782.530029   742.004028   772.640991   772.640991
# 2018-01-02   772.346008   914.830017   772.346008   884.443970   884.443970
# 2018-01-03   886.000000   974.471008   868.450989   962.719971   962.719971
# 2018-01-04   961.713013  1045.079956   946.085999   980.921997   980.921997
# 2018-01-05   975.750000  1075.390015   956.325012   997.719971   997.719971
# ...                 ...          ...          ...          ...          ...
# 2023-02-12  1539.776001  1545.554199  1501.462036  1515.033691  1515.033691
# 2023-02-13  1514.916992  1524.731445  1470.023926  1507.165894  1507.165894
# 2023-02-14  1506.992065  1562.034302  1497.194458  1556.875122  1556.875122
# 2023-02-15  1556.765137  1674.289795  1545.689697  1673.745972  1673.745972
# 2023-02-20  1684.290771  1716.489380  1659.509399  1698.305176  1698.305176
#
#                  Volume
# Date
# 2018-01-01   2595760128
# 2018-01-02   5783349760
# 2018-01-03   5093159936
# 2018-01-04   6502859776
# 2018-01-05   6683149824
# ...                 ...
# 2023-02-12   5319698775
# 2023-02-13   9363855114
# 2023-02-14   9249575045
# 2023-02-15  10015035156
# 2023-02-20   8091778048
#
# [1873 rows x 6 columns]
